# %%
from kafka import KafkaProducer
import json
from datetime import datetime, timezone
import time
import random

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# %%
def generate_sensor_data():
    return{
        'sensor_id': random.randint(1,5),
        'temperature': round(random.uniform(20.0, 40.0), 2),
        'humidity': round(random.uniform(30.0, 90.0), 2),
        'timestamp': time.time()
    }

# %%
try:
    while True:
        data = generate_sensor_data()
        print(f'Sending: {data}')
        producer.send('sensor-data', value=data)
        time.sleep(1)
except KeyboardInterrupt:
    print("Stopped by user")
finally:
    producer.close()
# Out:
# Sending: {'sensor_id': 3, 'temperature': 39.63, 'humidity': 59.11, 'timestamp': 1750062088.770572}
# Sending: {'sensor_id': 4, 'temperature': 34.11, 'humidity': 54.89, 'timestamp': 1750062089.8704295}
# Sending: {'sensor_id': 5, 'temperature': 34.04, 'humidity': 67.84, 'timestamp': 1750062090.87219}
# Sending: {'sensor_id': 5, 'temperature': 39.65, 'humidity': 69.74, 'timestamp': 1750062091.8730469}
# Sending: {'sensor_id': 2, 'temperature': 22.68, 'humidity': 36.59, 'timestamp': 1750062092.8751106}
# Sending: {'sensor_id': 3, 'temperature': 27.99, 'humidity': 81.25, 'timestamp': 1750062093.8759367}
# Sending: {'sensor_id': 5, 'temperature': 39.14, 'humidity': 76.47, 'timestamp': 1750062094.8771942}
# Sending: {'sensor_id': 4, 'temperature': 22.79, 'humidity': 58.29, 'timestamp': 1750062095.8780751}
# Sending: {'sensor_id': 1, 'temperature': 33.75, 'humidity': 58.25, 'timestamp': 1750062096.8792772}
# Sending: {'sensor_id': 2, 'temperature': 28.65, 'humidity': 70.19, 'timestamp': 1750062097.8800259}
# Sending: {'sensor_id': 1, 'temperature': 30.48, 'humidity': 67.28, 'timestamp': 1750062098.8810806}
# Sending: {'sensor_id': 1, 'temperature': 29.91, 'humidity': 46.96, 'timestamp': 1750062099.8818548}
# Sending: {'sensor_id': 5, 'temperature': 33.77, 'humidity': 31.22, 'timestamp': 1750062100.8832014}
# Sending: {'sensor_id': 5, 'temperature': 25.66, 'humidity': 67.36, 'timestamp': 1750062101.8846192}
# Sending: {'sensor_id': 4, 'temperature': 34.04, 'humidity': 53.55, 'timestamp': 1750062102.8857095}
# Sending: {'sensor_id': 4, 'temperature': 24.99, 'humidity': 34.3, 'timestamp': 1750062103.8864965}
# Sending: {'sensor_id': 5, 'temperature': 20.14, 'humidity': 60.97, 'timestamp': 1750062104.8877008}
# Sending: {'sensor_id': 5, 'temperature': 29.02, 'humidity': 87.7, 'timestamp': 1750062105.8889499}
# Sending: {'sensor_id': 3, 'temperature': 20.39, 'humidity': 42.61, 'timestamp': 1750062106.890556}
# Sending: {'sensor_id': 2, 'temperature': 28.41, 'humidity': 37.29, 'timestamp': 1750062107.8914702}
# Sending: {'sensor_id': 4, 'temperature': 20.05, 'humidity': 32.88, 'timestamp': 1750062108.8924954}
# Sending: {'sensor_id': 4, 'temperature': 22.72, 'humidity': 83.04, 'timestamp': 1750062109.8932788}
# Sending: {'sensor_id': 5, 'temperature': 37.72, 'humidity': 66.22, 'timestamp': 1750062110.8939466}
# Sending: {'sensor_id': 5, 'temperature': 39.04, 'humidity': 75.06, 'timestamp': 1750062111.895227}
# Sending: {'sensor_id': 5, 'temperature': 28.51, 'humidity': 33.03, 'timestamp': 1750062112.8964133}
# Sending: {'sensor_id': 4, 'temperature': 28.11, 'humidity': 57.98, 'timestamp': 1750062113.8976512}
# Sending: {'sensor_id': 3, 'temperature': 34.93, 'humidity': 75.99, 'timestamp': 1750062114.8987997}
# Sending: {'sensor_id': 2, 'temperature': 30.11, 'humidity': 48.18, 'timestamp': 1750062115.8998363}
# Sending: {'sensor_id': 2, 'temperature': 22.45, 'humidity': 67.59, 'timestamp': 1750062116.9008045}
# Sending: {'sensor_id': 5, 'temperature': 33.34, 'humidity': 63.37, 'timestamp': 1750062117.9025152}
# Sending: {'sensor_id': 3, 'temperature': 26.14, 'humidity': 63.71, 'timestamp': 1750062118.9034555}
# Sending: {'sensor_id': 2, 'temperature': 31.6, 'humidity': 30.94, 'timestamp': 1750062119.9044335}
# Sending: {'sensor_id': 4, 'temperature': 34.62, 'humidity': 35.77, 'timestamp': 1750062120.9052768}
# Sending: {'sensor_id': 1, 'temperature': 27.35, 'humidity': 57.06, 'timestamp': 1750062121.9059508}
# Sending: {'sensor_id': 5, 'temperature': 26.02, 'humidity': 59.11, 'timestamp': 1750062122.907052}
# Sending: {'sensor_id': 3, 'temperature': 20.27, 'humidity': 54.62, 'timestamp': 1750062123.90816}
# Sending: {'sensor_id': 4, 'temperature': 22.03, 'humidity': 36.8, 'timestamp': 1750062124.9089594}
# Sending: {'sensor_id': 1, 'temperature': 27.28, 'humidity': 87.27, 'timestamp': 1750062125.9102407}
# Sending: {'sensor_id': 3, 'temperature': 31.05, 'humidity': 86.89, 'timestamp': 1750062126.9110765}
# Sending: {'sensor_id': 1, 'temperature': 23.17, 'humidity': 88.93, 'timestamp': 1750062127.9122908}
# Sending: {'sensor_id': 5, 'temperature': 39.34, 'humidity': 79.78, 'timestamp': 1750062128.9132695}
# Sending: {'sensor_id': 5, 'temperature': 20.7, 'humidity': 84.44, 'timestamp': 1750062129.9143817}
# Sending: {'sensor_id': 5, 'temperature': 30.46, 'humidity': 80.24, 'timestamp': 1750062130.915526}
# Sending: {'sensor_id': 3, 'temperature': 30.72, 'humidity': 66.45, 'timestamp': 1750062131.916297}
# Sending: {'sensor_id': 3, 'temperature': 29.02, 'humidity': 80.05, 'timestamp': 1750062132.917562}
# Sending: {'sensor_id': 4, 'temperature': 26.31, 'humidity': 37.76, 'timestamp': 1750062133.9186368}
# Sending: {'sensor_id': 2, 'temperature': 36.54, 'humidity': 75.99, 'timestamp': 1750062134.9197867}
# Sending: {'sensor_id': 5, 'temperature': 30.43, 'humidity': 77.99, 'timestamp': 1750062135.9207466}
# Sending: {'sensor_id': 2, 'temperature': 28.76, 'humidity': 83.35, 'timestamp': 1750062136.9219003}
# Sending: {'sensor_id': 2, 'temperature': 25.3, 'humidity': 82.88, 'timestamp': 1750062137.9227014}
# Sending: {'sensor_id': 3, 'temperature': 37.99, 'humidity': 37.5, 'timestamp': 1750062138.92385}
# Sending: {'sensor_id': 2, 'temperature': 31.93, 'humidity': 84.38, 'timestamp': 1750062139.9247475}
# Sending: {'sensor_id': 5, 'temperature': 20.25, 'humidity': 48.55, 'timestamp': 1750062140.926004}
# Sending: {'sensor_id': 2, 'temperature': 30.03, 'humidity': 65.57, 'timestamp': 1750062141.926535}
# Sending: {'sensor_id': 1, 'temperature': 20.87, 'humidity': 81.45, 'timestamp': 1750062142.9277313}
# Sending: {'sensor_id': 4, 'temperature': 25.2, 'humidity': 67.87, 'timestamp': 1750062143.9285169}
# Sending: {'sensor_id': 5, 'temperature': 39.89, 'humidity': 30.0, 'timestamp': 1750062144.9300823}
# Sending: {'sensor_id': 2, 'temperature': 33.62, 'humidity': 38.41, 'timestamp': 1750062145.9308217}
# Sending: {'sensor_id': 1, 'temperature': 22.45, 'humidity': 75.74, 'timestamp': 1750062146.9313955}
# Sending: {'sensor_id': 3, 'temperature': 38.45, 'humidity': 34.8, 'timestamp': 1750062147.9321773}
# Sending: {'sensor_id': 1, 'temperature': 31.25, 'humidity': 37.37, 'timestamp': 1750062148.9331539}
# Sending: {'sensor_id': 5, 'temperature': 22.74, 'humidity': 33.27, 'timestamp': 1750062149.934582}
# Sending: {'sensor_id': 1, 'temperature': 28.23, 'humidity': 48.03, 'timestamp': 1750062150.9356759}
# Sending: {'sensor_id': 4, 'temperature': 28.14, 'humidity': 42.28, 'timestamp': 1750062151.9366758}
# Sending: {'sensor_id': 4, 'temperature': 28.93, 'humidity': 32.89, 'timestamp': 1750062152.9379764}
# Sending: {'sensor_id': 3, 'temperature': 20.68, 'humidity': 62.03, 'timestamp': 1750062153.9390998}
# Sending: {'sensor_id': 2, 'temperature': 32.24, 'humidity': 87.77, 'timestamp': 1750062154.939915}
# Sending: {'sensor_id': 5, 'temperature': 31.14, 'humidity': 41.75, 'timestamp': 1750062155.940935}
# Sending: {'sensor_id': 4, 'temperature': 20.65, 'humidity': 44.2, 'timestamp': 1750062156.9420521}
# Sending: {'sensor_id': 4, 'temperature': 20.86, 'humidity': 39.68, 'timestamp': 1750062157.942975}
# Sending: {'sensor_id': 4, 'temperature': 20.16, 'humidity': 53.12, 'timestamp': 1750062158.9439423}
# Sending: {'sensor_id': 2, 'temperature': 28.74, 'humidity': 55.84, 'timestamp': 1750062159.9446986}
# Sending: {'sensor_id': 1, 'temperature': 23.1, 'humidity': 62.03, 'timestamp': 1750062160.9459972}
# Sending: {'sensor_id': 5, 'temperature': 32.91, 'humidity': 32.54, 'timestamp': 1750062161.947119}
# Sending: {'sensor_id': 5, 'temperature': 31.1, 'humidity': 37.65, 'timestamp': 1750062162.947948}
# Sending: {'sensor_id': 1, 'temperature': 34.28, 'humidity': 77.35, 'timestamp': 1750062163.9490006}
# Sending: {'sensor_id': 3, 'temperature': 20.4, 'humidity': 77.15, 'timestamp': 1750062164.950475}
# Sending: {'sensor_id': 5, 'temperature': 31.42, 'humidity': 36.65, 'timestamp': 1750062165.9516027}
# Sending: {'sensor_id': 2, 'temperature': 31.88, 'humidity': 67.32, 'timestamp': 1750062166.9531455}
# Sending: {'sensor_id': 3, 'temperature': 28.08, 'humidity': 47.9, 'timestamp': 1750062167.9543126}
# Sending: {'sensor_id': 2, 'temperature': 32.31, 'humidity': 44.1, 'timestamp': 1750062168.9555833}
# Sending: {'sensor_id': 2, 'temperature': 32.03, 'humidity': 35.88, 'timestamp': 1750062169.9564292}
# Sending: {'sensor_id': 1, 'temperature': 38.44, 'humidity': 67.86, 'timestamp': 1750062170.957679}
# Sending: {'sensor_id': 5, 'temperature': 33.33, 'humidity': 48.57, 'timestamp': 1750062171.958899}
# Sending: {'sensor_id': 3, 'temperature': 21.01, 'humidity': 79.71, 'timestamp': 1750062172.9601893}
# Sending: {'sensor_id': 2, 'temperature': 37.12, 'humidity': 87.17, 'timestamp': 1750062173.9609225}
# Sending: {'sensor_id': 3, 'temperature': 20.14, 'humidity': 67.71, 'timestamp': 1750062174.9619308}
# Sending: {'sensor_id': 5, 'temperature': 37.33, 'humidity': 63.77, 'timestamp': 1750062175.9632714}
# Sending: {'sensor_id': 2, 'temperature': 20.76, 'humidity': 40.25, 'timestamp': 1750062176.9647706}
# Sending: {'sensor_id': 1, 'temperature': 23.82, 'humidity': 50.37, 'timestamp': 1750062177.966137}
# Sending: {'sensor_id': 3, 'temperature': 29.04, 'humidity': 55.06, 'timestamp': 1750062178.9676561}
# Sending: {'sensor_id': 1, 'temperature': 27.42, 'humidity': 85.62, 'timestamp': 1750062179.9685316}
# Sending: {'sensor_id': 3, 'temperature': 28.12, 'humidity': 85.29, 'timestamp': 1750062180.9696279}
# Sending: {'sensor_id': 5, 'temperature': 27.36, 'humidity': 43.99, 'timestamp': 1750062181.9707282}
# Sending: {'sensor_id': 1, 'temperature': 28.08, 'humidity': 47.23, 'timestamp': 1750062182.971938}
# Sending: {'sensor_id': 4, 'temperature': 24.76, 'humidity': 32.01, 'timestamp': 1750062183.9728363}
# Sending: {'sensor_id': 3, 'temperature': 32.92, 'humidity': 78.08, 'timestamp': 1750062184.9737697}
# Sending: {'sensor_id': 5, 'temperature': 36.45, 'humidity': 54.81, 'timestamp': 1750062185.975052}
# Sending: {'sensor_id': 2, 'temperature': 29.36, 'humidity': 66.83, 'timestamp': 1750062186.9760947}
# Sending: {'sensor_id': 5, 'temperature': 28.65, 'humidity': 58.77, 'timestamp': 1750062187.9773016}
# Sending: {'sensor_id': 5, 'temperature': 36.53, 'humidity': 47.55, 'timestamp': 1750062188.9782257}
# Sending: {'sensor_id': 4, 'temperature': 37.93, 'humidity': 89.07, 'timestamp': 1750062189.979115}
# Sending: {'sensor_id': 5, 'temperature': 30.93, 'humidity': 74.59, 'timestamp': 1750062190.980462}
# Sending: {'sensor_id': 4, 'temperature': 37.24, 'humidity': 77.51, 'timestamp': 1750062191.981995}
# Sending: {'sensor_id': 3, 'temperature': 27.35, 'humidity': 66.37, 'timestamp': 1750062192.9833372}
# Sending: {'sensor_id': 5, 'temperature': 31.32, 'humidity': 70.72, 'timestamp': 1750062193.984344}
# Sending: {'sensor_id': 1, 'temperature': 24.2, 'humidity': 49.8, 'timestamp': 1750062194.9851363}
# Sending: {'sensor_id': 5, 'temperature': 39.87, 'humidity': 56.69, 'timestamp': 1750062195.9862373}
# Sending: {'sensor_id': 3, 'temperature': 39.43, 'humidity': 59.96, 'timestamp': 1750062196.9873698}
# Sending: {'sensor_id': 5, 'temperature': 30.44, 'humidity': 85.05, 'timestamp': 1750062197.9883666}
# Sending: {'sensor_id': 4, 'temperature': 26.6, 'humidity': 36.66, 'timestamp': 1750062198.9892194}
# Sending: {'sensor_id': 2, 'temperature': 34.39, 'humidity': 33.59, 'timestamp': 1750062199.9899373}
# Sending: {'sensor_id': 1, 'temperature': 31.06, 'humidity': 32.68, 'timestamp': 1750062200.9914405}
# Sending: {'sensor_id': 4, 'temperature': 38.97, 'humidity': 75.04, 'timestamp': 1750062201.9924288}
# Sending: {'sensor_id': 4, 'temperature': 30.82, 'humidity': 49.65, 'timestamp': 1750062202.9939451}
# Sending: {'sensor_id': 1, 'temperature': 31.7, 'humidity': 53.17, 'timestamp': 1750062203.994837}
# Sending: {'sensor_id': 5, 'temperature': 23.98, 'humidity': 34.39, 'timestamp': 1750062204.9961624}
# Sending: {'sensor_id': 4, 'temperature': 23.25, 'humidity': 43.9, 'timestamp': 1750062205.9978313}
# Sending: {'sensor_id': 1, 'temperature': 22.35, 'humidity': 57.15, 'timestamp': 1750062206.9990826}
# Sending: {'sensor_id': 1, 'temperature': 25.79, 'humidity': 55.87, 'timestamp': 1750062207.9997334}
# Sending: {'sensor_id': 2, 'temperature': 24.07, 'humidity': 88.41, 'timestamp': 1750062209.0009944}
# Sending: {'sensor_id': 2, 'temperature': 38.69, 'humidity': 74.37, 'timestamp': 1750062210.0023022}
# Sending: {'sensor_id': 2, 'temperature': 26.29, 'humidity': 35.8, 'timestamp': 1750062211.0031397}
# Sending: {'sensor_id': 2, 'temperature': 33.03, 'humidity': 77.87, 'timestamp': 1750062212.004232}
# Sending: {'sensor_id': 5, 'temperature': 36.79, 'humidity': 56.24, 'timestamp': 1750062213.0056565}
# Sending: {'sensor_id': 2, 'temperature': 35.35, 'humidity': 77.03, 'timestamp': 1750062214.0068521}
# Sending: {'sensor_id': 4, 'temperature': 23.63, 'humidity': 85.43, 'timestamp': 1750062215.0079002}
# Sending: {'sensor_id': 3, 'temperature': 23.28, 'humidity': 86.79, 'timestamp': 1750062216.0089953}
# Sending: {'sensor_id': 2, 'temperature': 27.72, 'humidity': 77.03, 'timestamp': 1750062217.0099795}
# Sending: {'sensor_id': 3, 'temperature': 23.02, 'humidity': 78.78, 'timestamp': 1750062218.0108182}
# Sending: {'sensor_id': 1, 'temperature': 34.13, 'humidity': 70.42, 'timestamp': 1750062219.012922}
# Sending: {'sensor_id': 2, 'temperature': 37.25, 'humidity': 57.44, 'timestamp': 1750062220.014229}
# Sending: {'sensor_id': 4, 'temperature': 28.21, 'humidity': 67.76, 'timestamp': 1750062221.0154421}
# Sending: {'sensor_id': 1, 'temperature': 36.02, 'humidity': 33.45, 'timestamp': 1750062222.016251}
# Sending: {'sensor_id': 5, 'temperature': 20.75, 'humidity': 63.09, 'timestamp': 1750062223.01742}
# Sending: {'sensor_id': 5, 'temperature': 38.66, 'humidity': 85.89, 'timestamp': 1750062224.0183818}
# Sending: {'sensor_id': 5, 'temperature': 31.06, 'humidity': 69.17, 'timestamp': 1750062225.0199108}
# Sending: {'sensor_id': 4, 'temperature': 24.06, 'humidity': 38.12, 'timestamp': 1750062226.0213494}
# Stopped by user
