# %%
from kafka import KafkaProducer
import json
from datetime import datetime, timezone
import time
import random

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# %%
def generate_sensor_data():
    return{
        'sensor_id': random.randint(1,5),
        'temperature': round(random.uniform(20.0, 40.0), 2),
        'humidity': round(random.uniform(30.0, 90.0), 2),
        'timestamp': time.time()
    }

# %%
try:
    while True:
        data = generate_sensor_data()
        print(f'Sending: {data}')
        producer.send('sensor-data', value=data)
        time.sleep(1)
except KeyboardInterrupt:
    print("Stopped by user")
finally:
    producer.close()
# Out:
# Sending: {'sensor_id': 2, 'temperature': 38.53, 'humidity': 43.44, 'timestamp': 1749966838.8466418}
# Sending: {'sensor_id': 1, 'temperature': 25.16, 'humidity': 83.37, 'timestamp': 1749966839.9577866}
# Sending: {'sensor_id': 4, 'temperature': 20.15, 'humidity': 77.65, 'timestamp': 1749966840.9584365}
# Sending: {'sensor_id': 3, 'temperature': 35.13, 'humidity': 37.23, 'timestamp': 1749966841.9596741}
# Sending: {'sensor_id': 4, 'temperature': 31.87, 'humidity': 53.74, 'timestamp': 1749966842.960989}
# Sending: {'sensor_id': 5, 'temperature': 24.24, 'humidity': 84.41, 'timestamp': 1749966843.9621613}
# Sending: {'sensor_id': 3, 'temperature': 35.26, 'humidity': 38.75, 'timestamp': 1749966844.9642243}
# Sending: {'sensor_id': 3, 'temperature': 39.64, 'humidity': 74.99, 'timestamp': 1749966845.96515}
# Sending: {'sensor_id': 1, 'temperature': 20.69, 'humidity': 86.75, 'timestamp': 1749966846.9657156}
# Sending: {'sensor_id': 1, 'temperature': 29.12, 'humidity': 36.97, 'timestamp': 1749966847.966519}
# Sending: {'sensor_id': 5, 'temperature': 34.37, 'humidity': 73.9, 'timestamp': 1749966848.9679346}
# Sending: {'sensor_id': 5, 'temperature': 28.47, 'humidity': 77.97, 'timestamp': 1749966849.9689422}
# Sending: {'sensor_id': 4, 'temperature': 28.13, 'humidity': 62.98, 'timestamp': 1749966850.9697473}
# Sending: {'sensor_id': 2, 'temperature': 38.2, 'humidity': 68.6, 'timestamp': 1749966851.9708352}
# Sending: {'sensor_id': 5, 'temperature': 20.4, 'humidity': 54.06, 'timestamp': 1749966852.9720027}
# Sending: {'sensor_id': 5, 'temperature': 28.63, 'humidity': 72.98, 'timestamp': 1749966853.9728878}
# Sending: {'sensor_id': 2, 'temperature': 22.73, 'humidity': 89.85, 'timestamp': 1749966854.9736712}
# Sending: {'sensor_id': 5, 'temperature': 25.72, 'humidity': 41.46, 'timestamp': 1749966855.9749715}
# Sending: {'sensor_id': 1, 'temperature': 28.75, 'humidity': 74.04, 'timestamp': 1749966856.9762535}
# Sending: {'sensor_id': 3, 'temperature': 23.26, 'humidity': 39.03, 'timestamp': 1749966857.977642}
# Sending: {'sensor_id': 1, 'temperature': 27.78, 'humidity': 45.61, 'timestamp': 1749966858.9784136}
# Sending: {'sensor_id': 2, 'temperature': 25.69, 'humidity': 45.58, 'timestamp': 1749966859.9795592}
# Sending: {'sensor_id': 3, 'temperature': 27.71, 'humidity': 39.8, 'timestamp': 1749966860.9814773}
# Sending: {'sensor_id': 2, 'temperature': 26.81, 'humidity': 37.16, 'timestamp': 1749966861.982495}
# Sending: {'sensor_id': 2, 'temperature': 28.35, 'humidity': 64.35, 'timestamp': 1749966862.9831789}
# Sending: {'sensor_id': 5, 'temperature': 32.05, 'humidity': 71.61, 'timestamp': 1749966863.9845302}
# Sending: {'sensor_id': 3, 'temperature': 32.75, 'humidity': 39.82, 'timestamp': 1749966864.9855103}
# Sending: {'sensor_id': 5, 'temperature': 28.06, 'humidity': 50.94, 'timestamp': 1749966865.986306}
# Sending: {'sensor_id': 3, 'temperature': 28.38, 'humidity': 44.85, 'timestamp': 1749966866.9874954}
# Sending: {'sensor_id': 5, 'temperature': 20.33, 'humidity': 81.9, 'timestamp': 1749966867.9885712}
# Sending: {'sensor_id': 1, 'temperature': 28.7, 'humidity': 83.6, 'timestamp': 1749966868.9898217}
# Sending: {'sensor_id': 1, 'temperature': 37.66, 'humidity': 54.25, 'timestamp': 1749966869.9910004}
# Sending: {'sensor_id': 1, 'temperature': 20.84, 'humidity': 61.4, 'timestamp': 1749966870.9918096}
# Sending: {'sensor_id': 1, 'temperature': 24.05, 'humidity': 59.89, 'timestamp': 1749966871.9927006}
# Sending: {'sensor_id': 3, 'temperature': 21.08, 'humidity': 37.54, 'timestamp': 1749966872.9940221}
# Sending: {'sensor_id': 1, 'temperature': 20.8, 'humidity': 50.88, 'timestamp': 1749966873.9954967}
# Sending: {'sensor_id': 3, 'temperature': 20.39, 'humidity': 82.03, 'timestamp': 1749966874.9970157}
# Sending: {'sensor_id': 3, 'temperature': 35.55, 'humidity': 39.49, 'timestamp': 1749966875.9977734}
# Sending: {'sensor_id': 3, 'temperature': 39.44, 'humidity': 33.85, 'timestamp': 1749966876.9992104}
# Sending: {'sensor_id': 2, 'temperature': 23.48, 'humidity': 30.61, 'timestamp': 1749966878.0001466}
# Sending: {'sensor_id': 4, 'temperature': 32.64, 'humidity': 71.55, 'timestamp': 1749966879.001166}
# Sending: {'sensor_id': 4, 'temperature': 32.5, 'humidity': 83.94, 'timestamp': 1749966880.001931}
# Sending: {'sensor_id': 4, 'temperature': 31.62, 'humidity': 49.35, 'timestamp': 1749966881.0029125}
# Sending: {'sensor_id': 2, 'temperature': 26.16, 'humidity': 87.4, 'timestamp': 1749966882.003558}
# Sending: {'sensor_id': 2, 'temperature': 21.64, 'humidity': 40.92, 'timestamp': 1749966883.0044768}
# Sending: {'sensor_id': 1, 'temperature': 32.86, 'humidity': 46.58, 'timestamp': 1749966884.0054362}
# Sending: {'sensor_id': 2, 'temperature': 26.62, 'humidity': 41.86, 'timestamp': 1749966885.0065148}
# Sending: {'sensor_id': 5, 'temperature': 35.73, 'humidity': 87.63, 'timestamp': 1749966886.0078378}
# Sending: {'sensor_id': 3, 'temperature': 39.1, 'humidity': 42.53, 'timestamp': 1749966887.0092444}
# Sending: {'sensor_id': 1, 'temperature': 37.66, 'humidity': 61.29, 'timestamp': 1749966888.0103383}
# Sending: {'sensor_id': 1, 'temperature': 23.98, 'humidity': 47.15, 'timestamp': 1749966889.011552}
# Sending: {'sensor_id': 1, 'temperature': 24.54, 'humidity': 74.57, 'timestamp': 1749966890.012715}
# Sending: {'sensor_id': 2, 'temperature': 35.6, 'humidity': 83.13, 'timestamp': 1749966891.0136635}
# Sending: {'sensor_id': 1, 'temperature': 36.12, 'humidity': 44.26, 'timestamp': 1749966892.0148373}
# Sending: {'sensor_id': 4, 'temperature': 38.22, 'humidity': 75.11, 'timestamp': 1749966893.01686}
# Sending: {'sensor_id': 1, 'temperature': 22.29, 'humidity': 32.95, 'timestamp': 1749966894.0183277}
# Sending: {'sensor_id': 3, 'temperature': 27.72, 'humidity': 48.72, 'timestamp': 1749966895.0191174}
# Sending: {'sensor_id': 2, 'temperature': 32.1, 'humidity': 82.92, 'timestamp': 1749966896.020493}
# Sending: {'sensor_id': 5, 'temperature': 33.21, 'humidity': 72.23, 'timestamp': 1749966897.0218103}
# Sending: {'sensor_id': 1, 'temperature': 22.13, 'humidity': 62.19, 'timestamp': 1749966898.0227396}
# Sending: {'sensor_id': 5, 'temperature': 28.02, 'humidity': 89.03, 'timestamp': 1749966899.0241323}
# Sending: {'sensor_id': 1, 'temperature': 38.48, 'humidity': 53.26, 'timestamp': 1749966900.024666}
# Sending: {'sensor_id': 5, 'temperature': 25.45, 'humidity': 77.17, 'timestamp': 1749966901.0257125}
# Sending: {'sensor_id': 2, 'temperature': 31.81, 'humidity': 89.97, 'timestamp': 1749966902.0269697}
# Sending: {'sensor_id': 5, 'temperature': 25.09, 'humidity': 33.35, 'timestamp': 1749966903.027765}
# Sending: {'sensor_id': 5, 'temperature': 21.56, 'humidity': 52.51, 'timestamp': 1749966904.0287292}
# Sending: {'sensor_id': 4, 'temperature': 30.29, 'humidity': 33.21, 'timestamp': 1749966905.0294423}
# Sending: {'sensor_id': 3, 'temperature': 25.48, 'humidity': 40.31, 'timestamp': 1749966906.0302656}
# Sending: {'sensor_id': 1, 'temperature': 27.7, 'humidity': 47.77, 'timestamp': 1749966907.0315473}
# Sending: {'sensor_id': 3, 'temperature': 28.28, 'humidity': 46.2, 'timestamp': 1749966908.0326564}
# Sending: {'sensor_id': 5, 'temperature': 29.16, 'humidity': 64.29, 'timestamp': 1749966909.0339186}
# Sending: {'sensor_id': 5, 'temperature': 29.22, 'humidity': 70.56, 'timestamp': 1749966910.034752}
# Sending: {'sensor_id': 1, 'temperature': 22.71, 'humidity': 70.56, 'timestamp': 1749966911.0356398}
# Sending: {'sensor_id': 2, 'temperature': 28.08, 'humidity': 63.17, 'timestamp': 1749966912.0367372}
# Sending: {'sensor_id': 2, 'temperature': 29.07, 'humidity': 54.14, 'timestamp': 1749966913.0383043}
# Sending: {'sensor_id': 2, 'temperature': 32.55, 'humidity': 32.72, 'timestamp': 1749966914.0397308}
# Sending: {'sensor_id': 3, 'temperature': 26.63, 'humidity': 58.69, 'timestamp': 1749966915.0409222}
# Sending: {'sensor_id': 3, 'temperature': 29.4, 'humidity': 32.44, 'timestamp': 1749966916.0426729}
# Sending: {'sensor_id': 1, 'temperature': 38.46, 'humidity': 67.82, 'timestamp': 1749966917.0437212}
# Sending: {'sensor_id': 4, 'temperature': 24.25, 'humidity': 80.03, 'timestamp': 1749966918.0448968}
# Sending: {'sensor_id': 1, 'temperature': 29.3, 'humidity': 30.86, 'timestamp': 1749966919.046081}
# Sending: {'sensor_id': 5, 'temperature': 32.04, 'humidity': 52.65, 'timestamp': 1749966920.047247}
# Sending: {'sensor_id': 5, 'temperature': 29.96, 'humidity': 64.52, 'timestamp': 1749966921.0481777}
# Sending: {'sensor_id': 3, 'temperature': 28.48, 'humidity': 57.52, 'timestamp': 1749966922.0490053}
# Sending: {'sensor_id': 2, 'temperature': 31.99, 'humidity': 61.99, 'timestamp': 1749966923.0495455}
# Sending: {'sensor_id': 2, 'temperature': 22.72, 'humidity': 53.48, 'timestamp': 1749966924.050323}
# Sending: {'sensor_id': 5, 'temperature': 20.99, 'humidity': 38.29, 'timestamp': 1749966925.05109}
# Sending: {'sensor_id': 4, 'temperature': 21.1, 'humidity': 80.02, 'timestamp': 1749966926.0521598}
# Sending: {'sensor_id': 3, 'temperature': 22.7, 'humidity': 54.07, 'timestamp': 1749966927.0528102}
# Sending: {'sensor_id': 5, 'temperature': 34.84, 'humidity': 86.8, 'timestamp': 1749966928.0535624}
# Sending: {'sensor_id': 1, 'temperature': 36.84, 'humidity': 40.23, 'timestamp': 1749966929.054339}
# Sending: {'sensor_id': 5, 'temperature': 22.01, 'humidity': 60.29, 'timestamp': 1749966930.0557284}
# Sending: {'sensor_id': 4, 'temperature': 37.67, 'humidity': 79.73, 'timestamp': 1749966931.056641}
# Sending: {'sensor_id': 4, 'temperature': 29.75, 'humidity': 66.85, 'timestamp': 1749966932.0581703}
# Sending: {'sensor_id': 4, 'temperature': 33.82, 'humidity': 64.62, 'timestamp': 1749966933.0592136}
# Sending: {'sensor_id': 5, 'temperature': 20.8, 'humidity': 62.47, 'timestamp': 1749966934.0601735}
# Sending: {'sensor_id': 4, 'temperature': 30.43, 'humidity': 43.16, 'timestamp': 1749966935.061169}
# Sending: {'sensor_id': 2, 'temperature': 25.4, 'humidity': 48.97, 'timestamp': 1749966936.0623329}
# Sending: {'sensor_id': 5, 'temperature': 36.66, 'humidity': 42.45, 'timestamp': 1749966937.0633454}
# Sending: {'sensor_id': 4, 'temperature': 25.06, 'humidity': 45.93, 'timestamp': 1749966938.0646122}
# Sending: {'sensor_id': 5, 'temperature': 29.97, 'humidity': 73.0, 'timestamp': 1749966939.0655327}
# Sending: {'sensor_id': 1, 'temperature': 24.37, 'humidity': 48.89, 'timestamp': 1749966940.0662718}
# Sending: {'sensor_id': 5, 'temperature': 39.53, 'humidity': 49.04, 'timestamp': 1749966941.0670345}
# Sending: {'sensor_id': 1, 'temperature': 39.82, 'humidity': 50.4, 'timestamp': 1749966942.0680788}
# Sending: {'sensor_id': 3, 'temperature': 30.79, 'humidity': 36.7, 'timestamp': 1749966943.0699868}
# Sending: {'sensor_id': 5, 'temperature': 32.82, 'humidity': 34.57, 'timestamp': 1749966944.070965}
# Sending: {'sensor_id': 2, 'temperature': 23.46, 'humidity': 58.98, 'timestamp': 1749966945.0717642}
# Sending: {'sensor_id': 2, 'temperature': 29.77, 'humidity': 54.87, 'timestamp': 1749966946.0732841}
# Sending: {'sensor_id': 2, 'temperature': 38.72, 'humidity': 56.1, 'timestamp': 1749966947.074375}
# Sending: {'sensor_id': 4, 'temperature': 37.37, 'humidity': 42.9, 'timestamp': 1749966948.0755358}
# Sending: {'sensor_id': 1, 'temperature': 39.92, 'humidity': 84.07, 'timestamp': 1749966949.076593}
# Sending: {'sensor_id': 1, 'temperature': 23.82, 'humidity': 74.88, 'timestamp': 1749966950.0779018}
# Sending: {'sensor_id': 2, 'temperature': 27.56, 'humidity': 69.49, 'timestamp': 1749966951.0789526}
# Sending: {'sensor_id': 1, 'temperature': 30.53, 'humidity': 30.52, 'timestamp': 1749966952.0796728}
# Sending: {'sensor_id': 1, 'temperature': 23.95, 'humidity': 34.15, 'timestamp': 1749966953.0804753}
# Sending: {'sensor_id': 1, 'temperature': 26.16, 'humidity': 88.44, 'timestamp': 1749966954.0815668}
# Sending: {'sensor_id': 4, 'temperature': 27.0, 'humidity': 67.5, 'timestamp': 1749966955.082286}
# Sending: {'sensor_id': 4, 'temperature': 35.0, 'humidity': 44.21, 'timestamp': 1749966956.083577}
# Sending: {'sensor_id': 2, 'temperature': 36.7, 'humidity': 30.23, 'timestamp': 1749966957.0843236}
# Sending: {'sensor_id': 2, 'temperature': 26.99, 'humidity': 42.76, 'timestamp': 1749966958.0856278}
# Sending: {'sensor_id': 4, 'temperature': 28.92, 'humidity': 40.34, 'timestamp': 1749966959.0866163}
# Sending: {'sensor_id': 3, 'temperature': 31.57, 'humidity': 55.66, 'timestamp': 1749966960.087575}
# Sending: {'sensor_id': 5, 'temperature': 22.08, 'humidity': 32.51, 'timestamp': 1749966961.0891073}
# Sending: {'sensor_id': 1, 'temperature': 21.25, 'humidity': 88.74, 'timestamp': 1749966962.0904658}
# Sending: {'sensor_id': 2, 'temperature': 33.46, 'humidity': 59.04, 'timestamp': 1749966963.091285}
# Sending: {'sensor_id': 1, 'temperature': 29.37, 'humidity': 80.71, 'timestamp': 1749966964.092038}
# Sending: {'sensor_id': 4, 'temperature': 25.93, 'humidity': 33.75, 'timestamp': 1749966965.0927525}
# Sending: {'sensor_id': 4, 'temperature': 23.3, 'humidity': 47.73, 'timestamp': 1749966966.0933843}
# Sending: {'sensor_id': 3, 'temperature': 31.94, 'humidity': 47.62, 'timestamp': 1749966967.0943747}
# Sending: {'sensor_id': 2, 'temperature': 36.49, 'humidity': 56.11, 'timestamp': 1749966968.0949259}
# Sending: {'sensor_id': 1, 'temperature': 23.01, 'humidity': 80.03, 'timestamp': 1749966969.0962627}
# Sending: {'sensor_id': 4, 'temperature': 23.83, 'humidity': 88.98, 'timestamp': 1749966970.0975797}
# Sending: {'sensor_id': 4, 'temperature': 22.14, 'humidity': 42.09, 'timestamp': 1749966971.0984025}
# Sending: {'sensor_id': 5, 'temperature': 25.56, 'humidity': 48.17, 'timestamp': 1749966972.0992007}
# Sending: {'sensor_id': 1, 'temperature': 30.65, 'humidity': 76.61, 'timestamp': 1749966973.100378}
# Sending: {'sensor_id': 2, 'temperature': 24.92, 'humidity': 88.89, 'timestamp': 1749966974.101211}
# Sending: {'sensor_id': 2, 'temperature': 38.38, 'humidity': 30.49, 'timestamp': 1749966975.1030536}
# Sending: {'sensor_id': 3, 'temperature': 31.07, 'humidity': 58.42, 'timestamp': 1749966976.1038237}
# Sending: {'sensor_id': 3, 'temperature': 31.36, 'humidity': 76.98, 'timestamp': 1749966977.1051974}
# Sending: {'sensor_id': 1, 'temperature': 33.75, 'humidity': 59.13, 'timestamp': 1749966978.1062539}
# Sending: {'sensor_id': 5, 'temperature': 25.7, 'humidity': 42.41, 'timestamp': 1749966979.1077235}
# Sending: {'sensor_id': 5, 'temperature': 33.45, 'humidity': 37.26, 'timestamp': 1749966980.1086125}
# Sending: {'sensor_id': 3, 'temperature': 36.6, 'humidity': 63.48, 'timestamp': 1749966981.1099017}
# Sending: {'sensor_id': 5, 'temperature': 34.38, 'humidity': 66.82, 'timestamp': 1749966982.1110497}
# Sending: {'sensor_id': 4, 'temperature': 36.62, 'humidity': 46.29, 'timestamp': 1749966983.1122985}
# Sending: {'sensor_id': 5, 'temperature': 20.41, 'humidity': 77.85, 'timestamp': 1749966984.1137135}
# Sending: {'sensor_id': 5, 'temperature': 31.53, 'humidity': 72.21, 'timestamp': 1749966985.1148293}
# Sending: {'sensor_id': 5, 'temperature': 24.44, 'humidity': 54.87, 'timestamp': 1749966986.116097}
# Sending: {'sensor_id': 4, 'temperature': 29.22, 'humidity': 40.73, 'timestamp': 1749966987.1206198}
# Sending: {'sensor_id': 4, 'temperature': 34.13, 'humidity': 52.06, 'timestamp': 1749966988.124528}
# Sending: {'sensor_id': 1, 'temperature': 35.52, 'humidity': 87.91, 'timestamp': 1749966989.125847}
# Sending: {'sensor_id': 3, 'temperature': 25.04, 'humidity': 71.69, 'timestamp': 1749966990.1275406}
# Sending: {'sensor_id': 5, 'temperature': 34.16, 'humidity': 33.04, 'timestamp': 1749966991.1286905}
# Sending: {'sensor_id': 4, 'temperature': 31.28, 'humidity': 61.97, 'timestamp': 1749966992.130418}
# Sending: {'sensor_id': 4, 'temperature': 32.21, 'humidity': 69.35, 'timestamp': 1749966993.1316972}
# Sending: {'sensor_id': 5, 'temperature': 35.14, 'humidity': 41.22, 'timestamp': 1749966994.1331775}
# Sending: {'sensor_id': 4, 'temperature': 27.98, 'humidity': 86.27, 'timestamp': 1749966995.1341486}
# Sending: {'sensor_id': 2, 'temperature': 39.8, 'humidity': 51.74, 'timestamp': 1749966996.1352012}
# Sending: {'sensor_id': 2, 'temperature': 38.61, 'humidity': 30.99, 'timestamp': 1749966997.13622}
# Sending: {'sensor_id': 5, 'temperature': 37.19, 'humidity': 34.3, 'timestamp': 1749966998.137486}
# Sending: {'sensor_id': 3, 'temperature': 38.02, 'humidity': 42.39, 'timestamp': 1749966999.1389742}
# Sending: {'sensor_id': 5, 'temperature': 21.76, 'humidity': 75.66, 'timestamp': 1749967000.1400378}
# Stopped by user
